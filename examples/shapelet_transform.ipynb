# %%
"""
Example mainly mirrors from sktime with a few changes.
"""

from skshapelet.shapelet.shapelet_transform import BinaryShapeletTransform
from skshapelet.utils.validation import check_transform_series
from skshapelet.utils.validation import check_transform_X

import time
import sys
from datetime import datetime
from sklearn.pipeline import Pipeline

from skshapelet.datasets import load_dataset
from skshapelet.classifiers import classifier

dataset_name = "Car"

try:
    train_x, train_y, dist = load_dataset(name=dataset_name, split="train", return_X_y=True)
    test_x, test_y, _ = load_dataset(name=dataset_name, split="test", return_X_y=True, dist=dist)

    X_train, y_train = check_transform_series(train_x, train_y)
    X_test = check_transform_X(test_x)

    classifier = classifier.cid_to_classifier("xgb")

    timestamp = datetime.now()
    model_id = timestamp.strftime('%Y%m%d%H%M%S')

    pipeline = Pipeline(
        [
            (
                "st",
                BinaryShapeletTransform(
                    dataset_name,
                    model_id,
                    time_transform_in_mins=10,
                    num_candidates_to_sample_per_case=10,
                    random_seed=101
                ),
            ),
            classifier,
        ]
    )

    start = time.time()
    pipeline.fit(X_train, y_train)
    end_build = time.time()
    preds = pipeline.predict(X_test)
    end_test = time.time()

    print("Results:")
    print("Correct:")
    correct = sum(preds == test_y)
    print("\t" + str(correct) + "/" + str(len(test_y)))
    print("\t" + str(correct / len(test_y)))
    print("\nTiming:")
    print("\tTo build:   " + str(end_build - start) + " secs")
    print("\tTo predict: " + str(end_test - end_build) + " secs")

except:
    print("Unexpected error:", str(sys.exc_info()[1]).capitalize())
# Out:
# c:\users\hephaest\appdata\local\programs\python\python38\lib\site-packages\mass_ts-0.1.4-py3.8.egg\mass_ts\_mass_ts.py:17: UserWarning: GPU support will not work. You must pip install mass-ts[gpu].
#   warnings.warn(
# id:  47
# id:  9
# id:  11
# id:  34
# id:  6
# id:  53
# id:  38
# id:  28
# id:  10
# id:  22
# id:  30
# id:  12
# id:  42
# id:  1
# id:  19
# id:  25
# id:  36
# id:  7
# id:  59
# id:  55
# id:  16
# id:  21
# id:  15
# id:  24
# id:  0
# id:  29
# id:  39
# id:  35
# id:  50
# id:  57
# id:  4
# id:  58
# id:  13
# id:  40
# id:  52
# id:  48
# id:  23
# id:  51
# id:  2
# id:  32
# id:  26
# id:  33
# id:  31
# id:  37
# id:  20
# id:  8
# id:  45
# id:  17
# id:  5
# id:  49
# id:  3
# id:  27
# id:  43
# id:  41
# id:  46
# id:  56
# id:  54
# id:  44
# id:  14
# id:  18
# Fit time:  16.995428562164307
# Series ID: 4, start_pos: 207, length: 280, label:2, info_gain: 0.6167581525355638
# Series ID: 2, start_pos: 149, length: 384, label:2, info_gain: 0.6167581525355638
# Series ID: 31, start_pos: 159, length: 354, label:2, info_gain: 0.6167581525355638
# Series ID: 36, start_pos: 93, length: 194, label:0, info_gain: 0.5543814571441348
# Series ID: 26, start_pos: 81, length: 223, label:0, info_gain: 0.5543814571441348
# Series ID: 54, start_pos: 117, length: 180, label:0, info_gain: 0.5543814571441348
# Series ID: 0, start_pos: 102, length: 355, label:0, info_gain: 0.5451151262972096
# Series ID: 52, start_pos: 197, length: 183, label:2, info_gain: 0.5451151262972096
# Series ID: 45, start_pos: 170, length: 371, label:2, info_gain: 0.5451151262972096
# Series ID: 38, start_pos: 188, length: 232, label:2, info_gain: 0.5297683441112266
# Series ID: 30, start_pos: 119, length: 221, label:2, info_gain: 0.5086589542462276
# Series ID: 56, start_pos: 16, length: 255, label:2, info_gain: 0.5086589542462276
# Series ID: 16, start_pos: 108, length: 312, label:0, info_gain: 0.4812606939594128
# Series ID: 41, start_pos: 72, length: 386, label:0, info_gain: 0.4812606939594128
# Series ID: 15, start_pos: 11, length: 349, label:2, info_gain: 0.4812606939594128
# Series ID: 49, start_pos: 112, length: 408, label:2, info_gain: 0.4812606939594128
# Series ID: 43, start_pos: 129, length: 373, label:2, info_gain: 0.4812606939594128
# Series ID: 14, start_pos: 25, length: 323, label:2, info_gain: 0.4812606939594128
# Series ID: 10, start_pos: 182, length: 120, label:0, info_gain: 0.4545597237795976
# Series ID: 42, start_pos: 21, length: 305, label:0, info_gain: 0.4545597237795976
# Series ID: 17, start_pos: 11, length: 427, label:0, info_gain: 0.4545597237795976
# Series ID: 9, start_pos: 101, length: 205, label:1, info_gain: 0.4544330838339718
# Series ID: 47, start_pos: 137, length: 333, label:0, info_gain: 0.42307523883071974
# Series ID: 50, start_pos: 123, length: 277, label:0, info_gain: 0.42307523883071974
# Series ID: 20, start_pos: 61, length: 381, label:0, info_gain: 0.42307523883071974
# Series ID: 11, start_pos: 66, length: 243, label:2, info_gain: 0.42307523883071974
# Series ID: 19, start_pos: 57, length: 291, label:2, info_gain: 0.42307523883071974
# Series ID: 8, start_pos: 104, length: 265, label:1, info_gain: 0.4228737718249843
# Series ID: 27, start_pos: 72, length: 261, label:1, info_gain: 0.4228737718249843
# Series ID: 29, start_pos: 113, length: 246, label:1, info_gain: 0.3942615044461187
# Series ID: 59, start_pos: 53, length: 114, label:2, info_gain: 0.38480108179066824
# Series ID: 28, start_pos: 325, length: 165, label:3, info_gain: 0.37607934105596075
# Series ID: 5, start_pos: 118, length: 272, label:1, info_gain: 0.36952626201373917
# Series ID: 59, start_pos: 206, length: 246, label:2, info_gain: 0.3491373390752742
# Series ID: 23, start_pos: 110, length: 200, label:0, info_gain: 0.33186045105595596
# Series ID: 3, start_pos: 129, length: 203, label:0, info_gain: 0.33186045105595596
# Series ID: 53, start_pos: 34, length: 374, label:1, info_gain: 0.32471860145900244
# Series ID: 1, start_pos: 30, length: 295, label:1, info_gain: 0.32142474466286686
# Series ID: 25, start_pos: 261, length: 156, label:3, info_gain: 0.31616059433299465
# Series ID: 6, start_pos: 42, length: 423, label:0, info_gain: 0.3099915086619174
# Series ID: 35, start_pos: 348, length: 129, label:3, info_gain: 0.3097775401970416
# Series ID: 32, start_pos: 17, length: 369, label:3, info_gain: 0.3097775401970416
# Series ID: 37, start_pos: 24, length: 547, label:3, info_gain: 0.3097775401970416
# Series ID: 46, start_pos: 239, length: 140, label:1, info_gain: 0.3013940249458028
# Series ID: 22, start_pos: 116, length: 228, label:1, info_gain: 0.27785357530885935
# Series ID: 24, start_pos: 211, length: 345, label:3, info_gain: 0.27228192158867054
# Series ID: 28, start_pos: 64, length: 125, label:3, info_gain: 0.2624710183987866
# Series ID: 58, start_pos: 104, length: 268, label:3, info_gain: 0.2624710183987866
# Series ID: 57, start_pos: 102, length: 390, label:1, info_gain: 0.2623105959113545
# Series ID: 39, start_pos: 153, length: 165, label:2, info_gain: 0.24742092958007023
# Series ID: 51, start_pos: 52, length: 482, label:1, info_gain: 0.2384375814573293
# Series ID: 44, start_pos: 113, length: 240, label:1, info_gain: 0.23589926095864677
# Series ID: 18, start_pos: 193, length: 213, label:1, info_gain: 0.23589926095864677
# Series ID: 24, start_pos: 68, length: 85, label:3, info_gain: 0.23294448947517005
# Series ID: 48, start_pos: 233, length: 225, label:3, info_gain: 0.23120208014684307
# Series ID: 50, start_pos: 441, length: 64, label:0, info_gain: 0.2274935915144426
# Series ID: 11, start_pos: 323, length: 147, label:2, info_gain: 0.2274935915144426
# Series ID: 46, start_pos: 475, length: 47, label:1, info_gain: 0.2198766337138056
# Series ID: 33, start_pos: 393, length: 64, label:1, info_gain: 0.21551587744699507
# Series ID: 13, start_pos: 136, length: 369, label:0, info_gain: 0.20471745351938997
# Series ID: 12, start_pos: 179, length: 175, label:3, info_gain: 0.20417529930122225
# Series ID: 55, start_pos: 30, length: 369, label:3, info_gain: 0.20417529930122225
# Series ID: 40, start_pos: 212, length: 137, label:1, info_gain: 0.19773309845418174
# Series ID: 34, start_pos: 301, length: 177, label:3, info_gain: 0.193078808880435
# Series ID: 48, start_pos: 65, length: 126, label:3, info_gain: 0.18961019627449355
# Series ID: 48, start_pos: 467, length: 58, label:3, info_gain: 0.185488109985465
# Series ID: 7, start_pos: 68, length: 277, label:1, info_gain: 0.18353441617150157
# Series ID: 21, start_pos: 51, length: 418, label:1, info_gain: 0.18353441617150157
# Series ID: 35, start_pos: 4, length: 233, label:3, info_gain: 0.1756314336478943
# Series ID: 15, start_pos: 448, length: 47, label:2, info_gain: 0.1708513498505284
# Series ID: 32, start_pos: 452, length: 47, label:3, info_gain: 0.1364286469567555
# Series ID: 3, start_pos: 6, length: 96, label:0, info_gain: 0.10853790651058248
# Series ID: 26, start_pos: 23, length: 3, label:0, info_gain: 0.06955197468923358
# [22:04:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Series ID: 4, start_pos: 207, length: 280, label:2, info_gain: 0.6167581525355638
# Series ID: 2, start_pos: 149, length: 384, label:2, info_gain: 0.6167581525355638
# Series ID: 31, start_pos: 159, length: 354, label:2, info_gain: 0.6167581525355638
# Series ID: 36, start_pos: 93, length: 194, label:0, info_gain: 0.5543814571441348
# Series ID: 26, start_pos: 81, length: 223, label:0, info_gain: 0.5543814571441348
# Series ID: 54, start_pos: 117, length: 180, label:0, info_gain: 0.5543814571441348
# Series ID: 0, start_pos: 102, length: 355, label:0, info_gain: 0.5451151262972096
# Series ID: 52, start_pos: 197, length: 183, label:2, info_gain: 0.5451151262972096
# Series ID: 45, start_pos: 170, length: 371, label:2, info_gain: 0.5451151262972096
# Series ID: 38, start_pos: 188, length: 232, label:2, info_gain: 0.5297683441112266
# Series ID: 30, start_pos: 119, length: 221, label:2, info_gain: 0.5086589542462276
# Series ID: 56, start_pos: 16, length: 255, label:2, info_gain: 0.5086589542462276
# Series ID: 16, start_pos: 108, length: 312, label:0, info_gain: 0.4812606939594128
# Series ID: 41, start_pos: 72, length: 386, label:0, info_gain: 0.4812606939594128
# Series ID: 15, start_pos: 11, length: 349, label:2, info_gain: 0.4812606939594128
# Series ID: 49, start_pos: 112, length: 408, label:2, info_gain: 0.4812606939594128
# Series ID: 43, start_pos: 129, length: 373, label:2, info_gain: 0.4812606939594128
# Series ID: 14, start_pos: 25, length: 323, label:2, info_gain: 0.4812606939594128
# Series ID: 10, start_pos: 182, length: 120, label:0, info_gain: 0.4545597237795976
# Series ID: 42, start_pos: 21, length: 305, label:0, info_gain: 0.4545597237795976
# Series ID: 17, start_pos: 11, length: 427, label:0, info_gain: 0.4545597237795976
# Series ID: 9, start_pos: 101, length: 205, label:1, info_gain: 0.4544330838339718
# Series ID: 47, start_pos: 137, length: 333, label:0, info_gain: 0.42307523883071974
# Series ID: 50, start_pos: 123, length: 277, label:0, info_gain: 0.42307523883071974
# Series ID: 20, start_pos: 61, length: 381, label:0, info_gain: 0.42307523883071974
# Series ID: 11, start_pos: 66, length: 243, label:2, info_gain: 0.42307523883071974
# Series ID: 19, start_pos: 57, length: 291, label:2, info_gain: 0.42307523883071974
# Series ID: 8, start_pos: 104, length: 265, label:1, info_gain: 0.4228737718249843
# Series ID: 27, start_pos: 72, length: 261, label:1, info_gain: 0.4228737718249843
# Series ID: 29, start_pos: 113, length: 246, label:1, info_gain: 0.3942615044461187
# Series ID: 59, start_pos: 53, length: 114, label:2, info_gain: 0.38480108179066824
# Series ID: 28, start_pos: 325, length: 165, label:3, info_gain: 0.37607934105596075
# Series ID: 5, start_pos: 118, length: 272, label:1, info_gain: 0.36952626201373917
# Series ID: 59, start_pos: 206, length: 246, label:2, info_gain: 0.3491373390752742
# Series ID: 23, start_pos: 110, length: 200, label:0, info_gain: 0.33186045105595596
# Series ID: 3, start_pos: 129, length: 203, label:0, info_gain: 0.33186045105595596
# Series ID: 53, start_pos: 34, length: 374, label:1, info_gain: 0.32471860145900244
# Series ID: 1, start_pos: 30, length: 295, label:1, info_gain: 0.32142474466286686
# Series ID: 25, start_pos: 261, length: 156, label:3, info_gain: 0.31616059433299465
# Series ID: 6, start_pos: 42, length: 423, label:0, info_gain: 0.3099915086619174
# Series ID: 35, start_pos: 348, length: 129, label:3, info_gain: 0.3097775401970416
# Series ID: 32, start_pos: 17, length: 369, label:3, info_gain: 0.3097775401970416
# Series ID: 37, start_pos: 24, length: 547, label:3, info_gain: 0.3097775401970416
# Series ID: 46, start_pos: 239, length: 140, label:1, info_gain: 0.3013940249458028
# Series ID: 22, start_pos: 116, length: 228, label:1, info_gain: 0.27785357530885935
# Series ID: 24, start_pos: 211, length: 345, label:3, info_gain: 0.27228192158867054
# Series ID: 28, start_pos: 64, length: 125, label:3, info_gain: 0.2624710183987866
# Series ID: 58, start_pos: 104, length: 268, label:3, info_gain: 0.2624710183987866
# Series ID: 57, start_pos: 102, length: 390, label:1, info_gain: 0.2623105959113545
# Series ID: 39, start_pos: 153, length: 165, label:2, info_gain: 0.24742092958007023
# Series ID: 51, start_pos: 52, length: 482, label:1, info_gain: 0.2384375814573293
# Series ID: 44, start_pos: 113, length: 240, label:1, info_gain: 0.23589926095864677
# Series ID: 18, start_pos: 193, length: 213, label:1, info_gain: 0.23589926095864677
# Series ID: 24, start_pos: 68, length: 85, label:3, info_gain: 0.23294448947517005
# Series ID: 48, start_pos: 233, length: 225, label:3, info_gain: 0.23120208014684307
# Series ID: 50, start_pos: 441, length: 64, label:0, info_gain: 0.2274935915144426
# Series ID: 11, start_pos: 323, length: 147, label:2, info_gain: 0.2274935915144426
# Series ID: 46, start_pos: 475, length: 47, label:1, info_gain: 0.2198766337138056
# Series ID: 33, start_pos: 393, length: 64, label:1, info_gain: 0.21551587744699507
# Series ID: 13, start_pos: 136, length: 369, label:0, info_gain: 0.20471745351938997
# Series ID: 12, start_pos: 179, length: 175, label:3, info_gain: 0.20417529930122225
# Series ID: 55, start_pos: 30, length: 369, label:3, info_gain: 0.20417529930122225
# Series ID: 40, start_pos: 212, length: 137, label:1, info_gain: 0.19773309845418174
# Series ID: 34, start_pos: 301, length: 177, label:3, info_gain: 0.193078808880435
# Series ID: 48, start_pos: 65, length: 126, label:3, info_gain: 0.18961019627449355
# Series ID: 48, start_pos: 467, length: 58, label:3, info_gain: 0.185488109985465
# Series ID: 7, start_pos: 68, length: 277, label:1, info_gain: 0.18353441617150157
# Series ID: 21, start_pos: 51, length: 418, label:1, info_gain: 0.18353441617150157
# Series ID: 35, start_pos: 4, length: 233, label:3, info_gain: 0.1756314336478943
# Series ID: 15, start_pos: 448, length: 47, label:2, info_gain: 0.1708513498505284
# Series ID: 32, start_pos: 452, length: 47, label:3, info_gain: 0.1364286469567555
# Series ID: 3, start_pos: 6, length: 96, label:0, info_gain: 0.10853790651058248
# Series ID: 26, start_pos: 23, length: 3, label:0, info_gain: 0.06955197468923358
# Results:
# Correct:
# 	44/60
# 	0.7333333333333333
#
# Timing:
# 	To build:   20.060739278793335 secs
# 	To predict: 2.0415401458740234 secs
